# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Get today's date in seconds.
today = time.time()
today

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7fac2f97766a343fde5b88c555fc7061

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (e.g., clouds, fog, light rain, clear sky)
# The amount of rainfall over the last hour (1 hr).
# The amount of snowfall over the last hour (1 hr)
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
        # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')  
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:  
            city_snow = 0    
    except Exception as e:     
        # If an error is experienced, skip the city.
        print("City not found. Skipping...")
        pass
 
       
    # Append the city information into city_data list.        
    city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Description":city_description,
                      "Rain (inches)":city_rain,
                      "Snow (inches)":city_snow,                    
                      "Country": city_country
                     })

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | chifeng
# Processing Record 2 of Set 13 | pacific grove
# Processing Record 3 of Set 13 | bandarbeyla
# Processing Record 4 of Set 13 | vaini
# Processing Record 5 of Set 13 | yongan
# Processing Record 6 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 13 | beringovskiy
# Processing Record 8 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 13 | mataura
# Processing Record 10 of Set 13 | rikitea
# Processing Record 11 of Set 13 | busselton
# Processing Record 12 of Set 13 | pangnirtung
# Processing Record 13 of Set 13 | sinnamary
# Processing Record 14 of Set 13 | fukue
# Processing Record 15 of Set 13 | abu samrah
# Processing Record 16 of Set 13 | posse
# Processing Record 17 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 13 | hilo
# Processing Record 19 of Set 13 | chitral
# Processing Record 20 of Set 13 | saldanha
# Processing Record 21 of Set 13 | kapaa
# Processing Record 22 of Set 13 | kodiak
# Processing Record 23 of Set 13 | hobart
# Processing Record 24 of Set 13 | hambantota
# Processing Record 25 of Set 13 | wufeng
# Processing Record 26 of Set 13 | nenjiang
# Processing Record 27 of Set 13 | klaksvik
# Processing Record 28 of Set 13 | punta arenas
# Processing Record 29 of Set 13 | grand gaube
# Processing Record 30 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 13 | kropotkin
# Processing Record 32 of Set 13 | la ronge
# Processing Record 33 of Set 13 | coquimbo
# Processing Record 34 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 13 | ushuaia
# Processing Record 36 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 13 | darnah
# Processing Record 38 of Set 13 | pakenham
# Processing Record 39 of Set 13 | cabo san lucas
# Processing Record 40 of Set 13 | port alfred
# Processing Record 41 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 13 | fenoarivo
# Processing Record 43 of Set 13 | atuona
# Processing Record 44 of Set 13 | miri
# Processing Record 45 of Set 13 | sangar
# Processing Record 46 of Set 13 | eureka
# Processing Record 47 of Set 13 | ponta do sol
# Processing Record 48 of Set 13 | geraldton
# Processing Record 49 of Set 13 | shaartuz
# City not found. Skipping...
# Processing Record 50 of Set 13 | fairlie
# Processing Record 1 of Set 14 | butaritari
# Processing Record 2 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 14 | comodoro rivadavia
# Processing Record 4 of Set 14 | bluff
# Processing Record 5 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | caravelas
# Processing Record 7 of Set 14 | san patricio
# Processing Record 8 of Set 14 | matagami
# Processing Record 9 of Set 14 | albany
# Processing Record 10 of Set 14 | norman wells
# Processing Record 11 of Set 14 | port elizabeth
# Processing Record 12 of Set 14 | sikandarpur
# Processing Record 13 of Set 14 | buala
# Processing Record 14 of Set 14 | saint-philippe
# Processing Record 15 of Set 14 | ust-kut
# Processing Record 16 of Set 14 | iqaluit
# Processing Record 17 of Set 14 | imbituba
# Processing Record 18 of Set 14 | talcahuano
# Processing Record 19 of Set 14 | kavieng
# Processing Record 20 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 14 | san andres
# Processing Record 22 of Set 14 | jamestown
# Processing Record 23 of Set 14 | carnarvon
# Processing Record 24 of Set 14 | gweta
# Processing Record 25 of Set 14 | tiksi
# Processing Record 26 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 14 | buraydah
# Processing Record 28 of Set 14 | torbay
# Processing Record 29 of Set 14 | nome
# Processing Record 30 of Set 14 | akureyri
# Processing Record 31 of Set 14 | quatre cocos
# Processing Record 32 of Set 14 | tasiilaq
# Processing Record 33 of Set 14 | tikrit
# Processing Record 34 of Set 14 | kibi
# Processing Record 35 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 14 | juneau
# Processing Record 37 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 14 | mason city
# Processing Record 39 of Set 14 | rancho palos verdes
# Processing Record 40 of Set 14 | prince rupert
# Processing Record 41 of Set 14 | katsuura
# Processing Record 42 of Set 14 | simpang
# Processing Record 43 of Set 14 | tuatapere
# Processing Record 44 of Set 14 | hermanus
# Processing Record 45 of Set 14 | namibe
# Processing Record 46 of Set 14 | te anau
# Processing Record 47 of Set 14 | cutro
# Processing Record 48 of Set 14 | souillac
# Processing Record 49 of Set 14 | puerto ayora
# Processing Record 50 of Set 14 | khaniotis
# Processing Record 1 of Set 15 | cidreira
# Processing Record 2 of Set 15 | new norfolk
# Processing Record 3 of Set 15 | severo-kurilsk
# Processing Record 4 of Set 15 | castro
# Processing Record 5 of Set 15 | yellowknife
# Processing Record 6 of Set 15 | al
# City not found. Skipping...
# Processing Record 7 of Set 15 | conceicao do araguaia
# Processing Record 8 of Set 15 | taksimo
# Processing Record 9 of Set 15 | cape town
# Processing Record 10 of Set 15 | lompoc
# Processing Record 11 of Set 15 | mocuba
# Processing Record 12 of Set 15 | provideniya
# Processing Record 13 of Set 15 | lagoa
# Processing Record 14 of Set 15 | diapaga
# Processing Record 15 of Set 15 | lebu
# Processing Record 16 of Set 15 | saskylakh
# Processing Record 17 of Set 15 | avera
# Processing Record 18 of Set 15 | segezha
# Processing Record 19 of Set 15 | nanortalik
# Processing Record 20 of Set 15 | yatsushiro
# Processing Record 21 of Set 15 | tamandare
# Processing Record 22 of Set 15 | bathsheba
# Processing Record 23 of Set 15 | semnan
# Processing Record 24 of Set 15 | wangdiphodrang
# City not found. Skipping...
# Processing Record 25 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 15 | alofi
# Processing Record 27 of Set 15 | santa fe
# Processing Record 28 of Set 15 | vanimo
# Processing Record 29 of Set 15 | ilhabela
# Processing Record 30 of Set 15 | qaanaaq
# Processing Record 31 of Set 15 | porto novo
# Processing Record 32 of Set 15 | persianovskiy
# Processing Record 33 of Set 15 | clyde river
# Processing Record 34 of Set 15 | isangel
# Processing Record 35 of Set 15 | sarangani
# Processing Record 36 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 15 | victoria
# Processing Record 38 of Set 15 | poltavka
# Processing Record 39 of Set 15 | nikolskoye
# Processing Record 40 of Set 15 | kyshtovka
# Processing Record 41 of Set 15 | vao
# Processing Record 42 of Set 15 | olafsvik
# Processing Record 43 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 15 | obala
# Processing Record 46 of Set 15 | dikson
# Processing Record 47 of Set 15 | sorsk
# Processing Record 48 of Set 15 | bredasdorp
# Processing Record 49 of Set 15 | leningradskiy
# Processing Record 50 of Set 15 | barrow
# Processing Record 1 of Set 16 | mombetsu
# Processing Record 2 of Set 16 | mango
# Processing Record 3 of Set 16 | kysyl-syr
# Processing Record 4 of Set 16 | oyama
# Processing Record 5 of Set 16 | baglung
# Processing Record 6 of Set 16 | arlit
# Processing Record 7 of Set 16 | the pas
# Processing Record 8 of Set 16 | avarua
# Processing Record 9 of Set 16 | vestmanna
# Processing Record 10 of Set 16 | itainopolis
# Processing Record 11 of Set 16 | dumabato
# Processing Record 12 of Set 16 | east london
# Processing Record 13 of Set 16 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 16 | anadyr
# Processing Record 15 of Set 16 | lavrentiya
# Processing Record 16 of Set 16 | husavik
# Processing Record 17 of Set 16 | algiers
# Processing Record 18 of Set 16 | karratha
# Processing Record 19 of Set 16 | kaeo
# Processing Record 20 of Set 16 | touros
# Processing Record 21 of Set 16 | airai
# Processing Record 22 of Set 16 | atkinson
# Processing Record 23 of Set 16 | puquio
# Processing Record 24 of Set 16 | mayumba
# Processing Record 25 of Set 16 | paamiut
# Processing Record 26 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 16 | presidencia roque saenz pena
# Processing Record 28 of Set 16 | hearst
# Processing Record 29 of Set 16 | palmer
# Processing Record 30 of Set 16 | kovvur
# Processing Record 31 of Set 16 | yatou
# Processing Record 32 of Set 16 | arraial do cabo
# Processing Record 33 of Set 16 | anzhero-sudzhensk
# Processing Record 34 of Set 16 | chokurdakh
# Processing Record 35 of Set 16 | aklavik
# Processing Record 36 of Set 16 | koutiala
# Processing Record 37 of Set 16 | praia da vitoria
# Processing Record 38 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 16 | sioux lookout
# Processing Record 40 of Set 16 | coihaique
# Processing Record 41 of Set 16 | leh
# Processing Record 42 of Set 16 | male
# Processing Record 43 of Set 16 | yerbogachen
# Processing Record 44 of Set 16 | thompson
# Processing Record 45 of Set 16 | bitlis
# Processing Record 46 of Set 16 | faanui
# Processing Record 47 of Set 16 | tamworth
# Processing Record 48 of Set 16 | biak
# Processing Record 49 of Set 16 | blythe
# Processing Record 50 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 17 | abu zabad
# Processing Record 2 of Set 17 | sitka
# Processing Record 3 of Set 17 | boissevain
# Processing Record 4 of Set 17 | pemba
# Processing Record 5 of Set 17 | nyanguge
# Processing Record 6 of Set 17 | ouahigouya
# Processing Record 7 of Set 17 | rancho santa margarita
# Processing Record 8 of Set 17 | huarmey
# Processing Record 9 of Set 17 | cherskiy
# Processing Record 10 of Set 17 | dublin
# Processing Record 11 of Set 17 | upernavik
# Processing Record 12 of Set 17 | chakulia
# Processing Record 13 of Set 17 | port hawkesbury
# Processing Record 14 of Set 17 | valguarnera caropepe
# Processing Record 15 of Set 17 | mahebourg
# Processing Record 16 of Set 17 | amapa
# Processing Record 17 of Set 17 | kuryk
# Processing Record 18 of Set 17 | tuktoyaktuk
# Processing Record 19 of Set 17 | ginda
# Processing Record 20 of Set 17 | springdale
# Processing Record 21 of Set 17 | kunya
# Processing Record 22 of Set 17 | mandera
# Processing Record 23 of Set 17 | talara
# Processing Record 24 of Set 17 | antofagasta
# Processing Record 25 of Set 17 | srivilliputtur
# Processing Record 26 of Set 17 | mar del plata
# Processing Record 27 of Set 17 | twin falls
# Processing Record 28 of Set 17 | boshnyakovo
# Processing Record 29 of Set 17 | traverse city
# Processing Record 30 of Set 17 | kaitangata
# Processing Record 31 of Set 17 | dunedin
# Processing Record 32 of Set 17 | portland
# Processing Record 33 of Set 17 | rio gallegos
# Processing Record 34 of Set 17 | guerrero negro
# Processing Record 35 of Set 17 | les cayes
# Processing Record 36 of Set 17 | nuuk
# Processing Record 37 of Set 17 | bilibino
# Processing Record 38 of Set 17 | santa cruz
# Processing Record 39 of Set 17 | yakeshi
# Processing Record 40 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 17 | sturgis
# Processing Record 42 of Set 17 | aparecida do taboado
# Processing Record 43 of Set 17 | mugumu
# Processing Record 44 of Set 17 | maniitsoq
# Processing Record 45 of Set 17 | egvekinot
# Processing Record 46 of Set 17 | nizhniy kuranakh
# Processing Record 47 of Set 17 | fortuna
# Processing Record 48 of Set 17 | goderich
# Processing Record 49 of Set 17 | grindavik
# Processing Record 50 of Set 17 | pachino
# Processing Record 1 of Set 18 | grand baie
# Processing Record 2 of Set 18 | leo
# Processing Record 3 of Set 18 | kirakira
# Processing Record 4 of Set 18 | grandview
# Processing Record 5 of Set 18 | sechura
# Processing Record 6 of Set 18 | ibatiba
# Processing Record 7 of Set 18 | novodugino
# Processing Record 8 of Set 18 | budogoshch
# Processing Record 9 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 18 | karasjok
# Processing Record 11 of Set 18 | bethel
# Processing Record 12 of Set 18 | vila velha
# Processing Record 13 of Set 18 | khandbari
# Processing Record 14 of Set 18 | arica
# Processing Record 15 of Set 18 | uruzgan
# Processing Record 16 of Set 18 | abhar
# Processing Record 17 of Set 18 | hervey bay
# Processing Record 18 of Set 18 | sobolevo
# Processing Record 19 of Set 18 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 18 | stornoway
# Processing Record 21 of Set 18 | muros
# Processing Record 22 of Set 18 | vidim
# Processing Record 23 of Set 18 | karaton
# Processing Record 24 of Set 18 | muriwai beach
# Processing Record 25 of Set 18 | lakatoro
# Processing Record 26 of Set 18 | constitucion
# Processing Record 27 of Set 18 | khingansk
# Processing Record 28 of Set 18 | sorland
# Processing Record 29 of Set 18 | pevek
# Processing Record 30 of Set 18 | vardo
# Processing Record 31 of Set 18 | flagstaff
# Processing Record 32 of Set 18 | awjilah
# Processing Record 33 of Set 18 | kokopo
# Processing Record 34 of Set 18 | garoua
# Processing Record 35 of Set 18 | ribeira grande
# Processing Record 36 of Set 18 | denizli
# Processing Record 37 of Set 18 | abu dhabi
# Processing Record 38 of Set 18 | vozhega
# Processing Record 39 of Set 18 | salalah
# Processing Record 40 of Set 18 | puerto baquerizo moreno
# Processing Record 41 of Set 18 | cockburn town
# Processing Record 42 of Set 18 | waterloo
# Processing Record 43 of Set 18 | kenai
# Processing Record 44 of Set 18 | atambua
# Processing Record 45 of Set 18 | thinadhoo
# Processing Record 46 of Set 18 | kahului
# Processing Record 47 of Set 18 | davenda
# Processing Record 48 of Set 18 | ginir
# Processing Record 49 of Set 18 | zykovo
# Processing Record 50 of Set 18 | paramirim
# Processing Record 1 of Set 19 | seoul
# Processing Record 2 of Set 19 | uvinza
# Processing Record 3 of Set 19 | makakilo city
# Processing Record 4 of Set 19 | santiago
# Processing Record 5 of Set 19 | orel-izumrud
# Processing Record 6 of Set 19 | big spring
# Processing Record 7 of Set 19 | breves
# Processing Record 8 of Set 19 | srednekolymsk
# Processing Record 9 of Set 19 | chivacoa
# Processing Record 10 of Set 19 | nemuro
# Processing Record 11 of Set 19 | arman
# Processing Record 12 of Set 19 | kamina
# Processing Record 13 of Set 19 | dzhebariki-khaya
# Processing Record 14 of Set 19 | itupiranga
# Processing Record 15 of Set 19 | berlevag
# Processing Record 16 of Set 19 | riviere-au-renard
# Processing Record 17 of Set 19 | chai badan
# Processing Record 18 of Set 19 | acapulco
# Processing Record 19 of Set 19 | georgetown
# Processing Record 20 of Set 19 | ordynskoye
# Processing Record 21 of Set 19 | mitsamiouli
# Processing Record 22 of Set 19 | coroico
# Processing Record 23 of Set 19 | longyearbyen
# Processing Record 24 of Set 19 | annau
# Processing Record 25 of Set 19 | kruisfontein
# Processing Record 26 of Set 19 | mount isa
# Processing Record 27 of Set 19 | luderitz
# Processing Record 28 of Set 19 | chuguyevka
# Processing Record 29 of Set 19 | solnechnyy
# Processing Record 30 of Set 19 | kununurra
# Processing Record 31 of Set 19 | lundamo
# Processing Record 32 of Set 19 | golyshmanovo
# Processing Record 33 of Set 19 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 19 | namatanai
# Processing Record 35 of Set 19 | kushiro
# Processing Record 36 of Set 19 | vostok
# Processing Record 37 of Set 19 | lujan
# Processing Record 38 of Set 19 | narasannapeta
# Processing Record 39 of Set 19 | katha
# City not found. Skipping...
# Processing Record 40 of Set 19 | salinopolis
# Processing Record 41 of Set 19 | broome
# Processing Record 42 of Set 19 | chernyshevskiy
# Processing Record 43 of Set 19 | killybegs
# Processing Record 44 of Set 19 | fasa
# Processing Record 45 of Set 19 | majene
# Processing Record 46 of Set 19 | sakhnovshchyna
# Processing Record 47 of Set 19 | bar-le-duc
# Processing Record 48 of Set 19 | yeppoon
# Processing Record 49 of Set 19 | peto
# Processing Record 50 of Set 19 | nouadhibou
# Processing Record 1 of Set 20 | qaqortoq
# Processing Record 2 of Set 20 | hueytamalco
# Processing Record 3 of Set 20 | college
# Processing Record 4 of Set 20 | rajpipla
# Processing Record 5 of Set 20 | wawa
# Processing Record 6 of Set 20 | guajara-mirim
# City not found. Skipping...
# Processing Record 7 of Set 20 | mazyr
# Processing Record 8 of Set 20 | bengkulu
# Processing Record 9 of Set 20 | luau
# Processing Record 10 of Set 20 | denau
# City not found. Skipping...
# Processing Record 11 of Set 20 | cheney
# Processing Record 12 of Set 20 | chumikan
# Processing Record 13 of Set 20 | ostrovnoy
# Processing Record 14 of Set 20 | cayenne
# Processing Record 15 of Set 20 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 20 | yar-sale
# Processing Record 17 of Set 20 | redondela
# Processing Record 18 of Set 20 | borama
# City not found. Skipping...
# Processing Record 19 of Set 20 | akdepe
# Processing Record 20 of Set 20 | santa lucia
# Processing Record 21 of Set 20 | bolivar
# Processing Record 22 of Set 20 | tateyama
# Processing Record 23 of Set 20 | hamilton
# Processing Record 24 of Set 20 | pangoa
# Processing Record 25 of Set 20 | margate
# Processing Record 26 of Set 20 | lasa
# Processing Record 27 of Set 20 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 20 | iskateley
# Processing Record 29 of Set 20 | polyarnyy
# Processing Record 30 of Set 20 | colombo
# Processing Record 31 of Set 20 | antagan
# City not found. Skipping...
# Processing Record 32 of Set 20 | saint-joseph
# Processing Record 33 of Set 20 | san cristobal
# Processing Record 34 of Set 20 | mahajanga
# Processing Record 35 of Set 20 | tsabong
# Processing Record 36 of Set 20 | khromtau
# Processing Record 37 of Set 20 | asau
# Processing Record 38 of Set 20 | ko samui
# Processing Record 39 of Set 20 | yen bai
# Processing Record 40 of Set 20 | mount darwin
# Processing Record 41 of Set 20 | singaraja
# Processing Record 42 of Set 20 | ciro marina
# Processing Record 43 of Set 20 | ewa beach
# Processing Record 44 of Set 20 | abha
# Processing Record 45 of Set 20 | ust-uda
# Processing Record 46 of Set 20 | matangad
# Processing Record 47 of Set 20 | bogorodskoye
# Processing Record 48 of Set 20 | tabou
# Processing Record 49 of Set 20 | lincoln
# Processing Record 50 of Set 20 | khatanga
# Processing Record 1 of Set 21 | subaytilah
# City not found. Skipping...
# Processing Record 2 of Set 21 | pisco
# Processing Record 3 of Set 21 | saint-francois
# Processing Record 4 of Set 21 | green river
# Processing Record 5 of Set 21 | burica
# City not found. Skipping...
# Processing Record 6 of Set 21 | aksarka
# Processing Record 7 of Set 21 | maceio
# Processing Record 8 of Set 21 | troitskoye
# Processing Record 9 of Set 21 | diego de almagro
# Processing Record 10 of Set 21 | sao filipe
# Processing Record 11 of Set 21 | maragogi
# Processing Record 12 of Set 21 | tiznit
# Processing Record 13 of Set 21 | gushikawa
# Processing Record 14 of Set 21 | lovozero
# Processing Record 15 of Set 21 | progreso
# Processing Record 16 of Set 21 | severobaykalsk
# Processing Record 17 of Set 21 | beloha
# Processing Record 18 of Set 21 | tambul
# City not found. Skipping...
# Processing Record 19 of Set 21 | lashio
# Processing Record 20 of Set 21 | udachnyy
# Processing Record 21 of Set 21 | walvis bay
# Processing Record 22 of Set 21 | padang
# Processing Record 23 of Set 21 | flinders
# Processing Record 24 of Set 21 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 21 | jamame
# Processing Record 26 of Set 21 | paita
# Processing Record 27 of Set 21 | imeni poliny osipenko
# Processing Record 28 of Set 21 | lumphat
# Processing Record 29 of Set 21 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 21 | belaya gora
# Processing Record 31 of Set 21 | labuan
# Processing Record 32 of Set 21 | yulara
# Processing Record 33 of Set 21 | liverpool
# Processing Record 34 of Set 21 | terrasini
# Processing Record 35 of Set 21 | hofn
# Processing Record 36 of Set 21 | neiafu
# Processing Record 37 of Set 21 | oban
# Processing Record 38 of Set 21 | hithadhoo
# Processing Record 39 of Set 21 | camacupa
# Processing Record 40 of Set 21 | urshelskiy
# Processing Record 41 of Set 21 | muyezerskiy
# Processing Record 42 of Set 21 | melbu
# Processing Record 43 of Set 21 | jumla
# Processing Record 44 of Set 21 | narsaq
# Processing Record 45 of Set 21 | aykhal
# Processing Record 46 of Set 21 | vikersund
# Processing Record 47 of Set 21 | deep river
# Processing Record 48 of Set 21 | ugoofaaru
# Processing Record 49 of Set 21 | priargunsk
# Processing Record 50 of Set 21 | mount gambier
# Processing Record 1 of Set 22 | harper
# Processing Record 2 of Set 22 | ahipara
# Processing Record 3 of Set 22 | ilulissat
# Processing Record 4 of Set 22 | manali
# Processing Record 5 of Set 22 | behren-les-forbach
# Processing Record 6 of Set 22 | haines junction
# Processing Record 7 of Set 22 | outjo
# Processing Record 8 of Set 22 | bima
# Processing Record 9 of Set 22 | rawson
# Processing Record 10 of Set 22 | la gaulette
# City not found. Skipping...
# Processing Record 11 of Set 22 | hay river
# Processing Record 12 of Set 22 | okha
# Processing Record 13 of Set 22 | tura
# Processing Record 14 of Set 22 | hisua
# Processing Record 15 of Set 22 | moundsville
# Processing Record 16 of Set 22 | kankakee
# Processing Record 17 of Set 22 | marsh harbour
# Processing Record 18 of Set 22 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 22 | saint-leu
# Processing Record 20 of Set 22 | yaan
# Processing Record 21 of Set 22 | vila franca do campo
# Processing Record 22 of Set 22 | galiakot
# Processing Record 23 of Set 22 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 22 | westport
# Processing Record 25 of Set 22 | eston
# Processing Record 26 of Set 22 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 22 | gurupa
# Processing Record 28 of Set 22 | sebeta
# Processing Record 29 of Set 22 | sai buri
# Processing Record 30 of Set 22 | kem
# Processing Record 31 of Set 22 | blackpool
# Processing Record 32 of Set 22 | marawi
# Processing Record 33 of Set 22 | kodinsk
# Processing Record 34 of Set 22 | alice springs
# Processing Record 35 of Set 22 | lima
# Processing Record 36 of Set 22 | grammichele
# Processing Record 37 of Set 22 | dharmavaram
# Processing Record 38 of Set 22 | southbridge
# Processing Record 39 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 22 | zhangye
# Processing Record 41 of Set 22 | raipur
# Processing Record 42 of Set 22 | esperance
# Processing Record 43 of Set 22 | harindanga
# Processing Record 44 of Set 22 | naze
# Processing Record 45 of Set 22 | jinchang
# Processing Record 46 of Set 22 | belyy yar
# Processing Record 47 of Set 22 | umm kaddadah
# Processing Record 48 of Set 22 | yenagoa
# Processing Record 49 of Set 22 | barra velha
# Processing Record 50 of Set 22 | marzuq
# Processing Record 1 of Set 23 | chapleau
# Processing Record 2 of Set 23 | nampula
# Processing Record 3 of Set 23 | hobyo
# Processing Record 4 of Set 23 | bac lieu
# Processing Record 5 of Set 23 | mana
# Processing Record 6 of Set 23 | lookan
# Processing Record 7 of Set 23 | san ignacio
# Processing Record 8 of Set 23 | iwaki
# Processing Record 9 of Set 23 | camacha
# Processing Record 10 of Set 23 | versalles
# Processing Record 11 of Set 23 | uige
# Processing Record 12 of Set 23 | poya
# Processing Record 13 of Set 23 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 23 | chadan
# Processing Record 15 of Set 23 | siva
# Processing Record 16 of Set 23 | ozinki
# Processing Record 17 of Set 23 | brooks
# Processing Record 18 of Set 23 | minot
# Processing Record 19 of Set 23 | bishopbriggs
# Processing Record 20 of Set 23 | langham
# Processing Record 21 of Set 23 | sisimiut
# Processing Record 22 of Set 23 | xining
# Processing Record 23 of Set 23 | manacapuru
# Processing Record 24 of Set 23 | kamenka
# Processing Record 25 of Set 23 | morondava
# Processing Record 26 of Set 23 | komsomolskiy
# Processing Record 27 of Set 23 | seymchan
# Processing Record 28 of Set 23 | idanre
# Processing Record 29 of Set 23 | paso de carrasco
# Processing Record 30 of Set 23 | gazojak
# Processing Record 31 of Set 23 | ulagan
# Processing Record 32 of Set 23 | rio grande
# Processing Record 33 of Set 23 | ban nahin
# Processing Record 34 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 23 | norsup
# Processing Record 36 of Set 23 | vila
# Processing Record 37 of Set 23 | staryy nadym
# Processing Record 38 of Set 23 | dzilam gonzalez
# Processing Record 39 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 23 | chuy
# Processing Record 41 of Set 23 | yuksekova
# Processing Record 42 of Set 23 | catalina
# Processing Record 43 of Set 23 | laredo
# Processing Record 44 of Set 23 | stromness
# Processing Record 45 of Set 23 | port lincoln
# Processing Record 46 of Set 23 | talnakh
# Processing Record 47 of Set 23 | raudeberg
# Processing Record 48 of Set 23 | jaciara
# Processing Record 49 of Set 23 | starotimoshkino
# Processing Record 50 of Set 23 | ust-barguzin
# Processing Record 1 of Set 24 | krasnoselkup
# Processing Record 2 of Set 24 | gat
# Processing Record 3 of Set 24 | manta
# Processing Record 4 of Set 24 | ancud
# Processing Record 5 of Set 24 | peruwelz
# Processing Record 6 of Set 24 | saint george
# Processing Record 7 of Set 24 | bereda
# Processing Record 8 of Set 24 | laguna
# Processing Record 9 of Set 24 | novoilinsk
# Processing Record 10 of Set 24 | broken hill
# Processing Record 11 of Set 24 | port-gentil
# Processing Record 12 of Set 24 | mendi
# Processing Record 13 of Set 24 | fez
# Processing Record 14 of Set 24 | zhigansk
# Processing Record 15 of Set 24 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 24 | san ramon de la nueva oran
# Processing Record 17 of Set 24 | mattoon
# Processing Record 18 of Set 24 | nowy dwor gdanski
# Processing Record 19 of Set 24 | plettenberg bay
# Processing Record 20 of Set 24 | honningsvag
# Processing Record 21 of Set 24 | bayir
# Processing Record 22 of Set 24 | aripuana
# Processing Record 23 of Set 24 | shorapani
# Processing Record 24 of Set 24 | yarada
# Processing Record 25 of Set 24 | lufilufi
# Processing Record 26 of Set 24 | ulaangom
# Processing Record 27 of Set 24 | tommot
# Processing Record 28 of Set 24 | rawah
# Processing Record 29 of Set 24 | pozo colorado
# Processing Record 30 of Set 24 | hibbing
# Processing Record 31 of Set 24 | pierre
# Processing Record 32 of Set 24 | los llanos de aridane
# Processing Record 33 of Set 24 | mehamn
# Processing Record 34 of Set 24 | half moon bay
# Processing Record 35 of Set 24 | ornskoldsvik
# Processing Record 36 of Set 24 | mahmudia
# Processing Record 37 of Set 24 | khorinsk
# Processing Record 38 of Set 24 | koindu
# Processing Record 39 of Set 24 | wrexham
# Processing Record 40 of Set 24 | ghanzi
# Processing Record 41 of Set 24 | havre-saint-pierre
# Processing Record 42 of Set 24 | predivinsk
# Processing Record 43 of Set 24 | pando
# Processing Record 44 of Set 24 | codrington
# Processing Record 45 of Set 24 | we
# City not found. Skipping...
# Processing Record 46 of Set 24 | whitianga
# Processing Record 47 of Set 24 | teruel
# Processing Record 48 of Set 24 | miami
# Processing Record 49 of Set 24 | koungou
# Processing Record 50 of Set 24 | skjervoy
# Processing Record 1 of Set 25 | dicabisagan
# Processing Record 2 of Set 25 | aba
# Processing Record 3 of Set 25 | poum
# Processing Record 4 of Set 25 | matay
# Processing Record 5 of Set 25 | sungaipenuh
# Processing Record 6 of Set 25 | axim
# Processing Record 7 of Set 25 | port hedland
# Processing Record 8 of Set 25 | barcelos
# Processing Record 9 of Set 25 | lidorikion
# City not found. Skipping...
# Processing Record 10 of Set 25 | uppsala
# Processing Record 11 of Set 25 | cortez
# Processing Record 12 of Set 25 | haveri
# Processing Record 13 of Set 25 | hami
# Processing Record 14 of Set 25 | trinidad
# Processing Record 15 of Set 25 | muli
# Processing Record 16 of Set 25 | moose factory
# Processing Record 17 of Set 25 | casas grandes
# Processing Record 18 of Set 25 | tuta
# Processing Record 19 of Set 25 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 25 | darlowo
# Processing Record 21 of Set 25 | evans
# Processing Record 22 of Set 25 | alanya
# Processing Record 23 of Set 25 | lodwar
# Processing Record 24 of Set 25 | bakchar
# Processing Record 25 of Set 25 | innisfail
# Processing Record 26 of Set 25 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 25 | lahad datu
# Processing Record 28 of Set 25 | kolokani
# Processing Record 29 of Set 25 | kendari
# Processing Record 30 of Set 25 | bobrov
# Processing Record 31 of Set 25 | garowe
# Processing Record 32 of Set 25 | balykshi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
len(city_data)
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description","Rain (inches)","Snow (inches)"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Chifeng      CN  42.27  118.96     75.43        53          28
# 1  Pacific Grove      US  36.62 -121.92     70.00        63          40
# 2    Bandarbeyla      SO   9.49   50.81     79.63        73          99
# 3          Vaini      TO -21.20 -175.20     78.80        78          75
# 4         Yongan      CN  39.70  113.69     72.25        53           0
#
#    Wind Speed       Description  Rain (in)  Snow (in)
# 0        4.90  scattered clouds        0.0        0.0
# 1       10.29  scattered clouds        0.0        0.0
# 2       27.83   overcast clouds        0.0        0.0
# 3        8.05     broken clouds        0.0        0.0
# 4        2.95         clear sky        0.0        0.0

# %%
# Save the new DataFrame as a CSV file to be used for Part 2.
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Upload the CSV file as part of your submission as WeatherPy_database.csv.
