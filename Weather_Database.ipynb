# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Get today's date in seconds.
today = time.time()
today

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7fac2f97766a343fde5b88c555fc7061

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (e.g., clouds, fog, light rain, clear sky)
# The amount of rainfall over the last hour (1 hr).
# The amount of snowfall over the last hour (1 hr)
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
        # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')  
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError:  
            city_snow = 0    
    except Exception as e:     
        # If an error is experienced, skip the city.
        print("City not found. Skipping...")
        pass
 
       
    # Append the city information into city_data list.        
    city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Description":city_description,
                      "Rain (inches)":city_rain,
                      "Snow (inches)":city_snow,                    
                      "Country": city_country
                     })

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | dikson
# Processing Record 2 of Set 13 | beni mazar
# Processing Record 3 of Set 13 | sao miguel do araguaia
# Processing Record 4 of Set 13 | namibe
# Processing Record 5 of Set 13 | barrow
# Processing Record 6 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 13 | aykhal
# Processing Record 8 of Set 13 | comodoro rivadavia
# Processing Record 9 of Set 13 | griffith
# Processing Record 10 of Set 13 | upernavik
# Processing Record 11 of Set 13 | mnogovershinnyy
# Processing Record 12 of Set 13 | soligalich
# Processing Record 13 of Set 13 | vila velha
# Processing Record 14 of Set 13 | yellowknife
# Processing Record 15 of Set 13 | saskylakh
# Processing Record 16 of Set 13 | hirado
# Processing Record 17 of Set 13 | provideniya
# Processing Record 18 of Set 13 | jamestown
# Processing Record 19 of Set 13 | puerto ayora
# Processing Record 20 of Set 13 | iranshahr
# Processing Record 21 of Set 13 | inongo
# Processing Record 22 of Set 13 | oceanside
# Processing Record 23 of Set 13 | katsuura
# Processing Record 24 of Set 13 | atherton
# Processing Record 25 of Set 13 | san policarpo
# Processing Record 26 of Set 13 | busselton
# Processing Record 27 of Set 13 | manaure
# Processing Record 28 of Set 13 | rawson
# Processing Record 29 of Set 13 | ushuaia
# Processing Record 30 of Set 13 | gamba
# Processing Record 31 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 13 | moron
# Processing Record 33 of Set 13 | albany
# Processing Record 34 of Set 13 | cape town
# Processing Record 35 of Set 13 | ancud
# Processing Record 36 of Set 13 | ostrovnoy
# Processing Record 37 of Set 13 | hohhot
# Processing Record 38 of Set 13 | isangel
# Processing Record 39 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 13 | san jeronimo
# Processing Record 41 of Set 13 | berdigestyakh
# Processing Record 42 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 13 | puerto cabezas
# Processing Record 44 of Set 13 | touros
# Processing Record 45 of Set 13 | antalaha
# Processing Record 46 of Set 13 | bukama
# Processing Record 47 of Set 13 | rikitea
# Processing Record 48 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 13 | laredo
# Processing Record 50 of Set 13 | necochea
# Processing Record 1 of Set 14 | codrington
# Processing Record 2 of Set 14 | hilo
# Processing Record 3 of Set 14 | mattru
# Processing Record 4 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 14 | hobart
# Processing Record 6 of Set 14 | kaitangata
# Processing Record 7 of Set 14 | guerrero negro
# Processing Record 8 of Set 14 | puerto baquerizo moreno
# Processing Record 9 of Set 14 | thompson
# Processing Record 10 of Set 14 | severo-kurilsk
# Processing Record 11 of Set 14 | chokurdakh
# Processing Record 12 of Set 14 | luderitz
# Processing Record 13 of Set 14 | tasiilaq
# Processing Record 14 of Set 14 | souillac
# Processing Record 15 of Set 14 | vaini
# Processing Record 16 of Set 14 | mount isa
# Processing Record 17 of Set 14 | katherine
# Processing Record 18 of Set 14 | half moon bay
# Processing Record 19 of Set 14 | punta arenas
# Processing Record 20 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 14 | mombetsu
# Processing Record 22 of Set 14 | ahipara
# Processing Record 23 of Set 14 | huitziltepec
# Processing Record 24 of Set 14 | bredasdorp
# Processing Record 25 of Set 14 | cherskiy
# Processing Record 26 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 14 | taunggyi
# Processing Record 28 of Set 14 | kinshasa
# Processing Record 29 of Set 14 | mataura
# Processing Record 30 of Set 14 | asau
# Processing Record 31 of Set 14 | arys
# Processing Record 32 of Set 14 | shache
# Processing Record 33 of Set 14 | mana
# Processing Record 34 of Set 14 | kapaa
# Processing Record 35 of Set 14 | parras
# City not found. Skipping...
# Processing Record 36 of Set 14 | morondava
# Processing Record 37 of Set 14 | los llanos de aridane
# Processing Record 38 of Set 14 | tiksi
# Processing Record 39 of Set 14 | buraydah
# Processing Record 40 of Set 14 | zhangye
# Processing Record 41 of Set 14 | masallatah
# Processing Record 42 of Set 14 | qaanaaq
# Processing Record 43 of Set 14 | kargasok
# Processing Record 44 of Set 14 | kamenskiy
# Processing Record 45 of Set 14 | abu samrah
# Processing Record 46 of Set 14 | kavaratti
# Processing Record 47 of Set 14 | arraial do cabo
# Processing Record 48 of Set 14 | yulara
# Processing Record 49 of Set 14 | adrar
# Processing Record 50 of Set 14 | butaritari
# Processing Record 1 of Set 15 | whitecourt
# Processing Record 2 of Set 15 | avarua
# Processing Record 3 of Set 15 | castro
# Processing Record 4 of Set 15 | meulaboh
# Processing Record 5 of Set 15 | mar del plata
# Processing Record 6 of Set 15 | ati
# Processing Record 7 of Set 15 | nikolskoye
# Processing Record 8 of Set 15 | wanderlandia
# City not found. Skipping...
# Processing Record 9 of Set 15 | fairbanks
# Processing Record 10 of Set 15 | cockburn town
# Processing Record 11 of Set 15 | cabo san lucas
# Processing Record 12 of Set 15 | dicabisagan
# Processing Record 13 of Set 15 | abu dhabi
# Processing Record 14 of Set 15 | grand gaube
# Processing Record 15 of Set 15 | bethel
# Processing Record 16 of Set 15 | constitucion
# Processing Record 17 of Set 15 | itoman
# Processing Record 18 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 15 | deputatskiy
# Processing Record 20 of Set 15 | cam ranh
# Processing Record 21 of Set 15 | verkhoturye
# Processing Record 22 of Set 15 | santa fe
# Processing Record 23 of Set 15 | ola
# Processing Record 24 of Set 15 | carnarvon
# Processing Record 25 of Set 15 | zeya
# Processing Record 26 of Set 15 | westport
# Processing Record 27 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 15 | kodiak
# Processing Record 29 of Set 15 | new norfolk
# Processing Record 30 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 15 | samarai
# Processing Record 32 of Set 15 | ornskoldsvik
# Processing Record 33 of Set 15 | bend
# Processing Record 34 of Set 15 | terekli-mekteb
# Processing Record 35 of Set 15 | palmira
# Processing Record 36 of Set 15 | la primavera
# Processing Record 37 of Set 15 | manavalakurichi
# Processing Record 38 of Set 15 | petukhovo
# Processing Record 39 of Set 15 | chuy
# Processing Record 40 of Set 15 | atuona
# Processing Record 41 of Set 15 | sozimskiy
# Processing Record 42 of Set 15 | tirumullaivasal
# Processing Record 43 of Set 15 | komsomolskiy
# Processing Record 44 of Set 15 | klaksvik
# Processing Record 45 of Set 15 | paralimni
# Processing Record 46 of Set 15 | abu zabad
# Processing Record 47 of Set 15 | victoria
# Processing Record 48 of Set 15 | vardo
# Processing Record 49 of Set 15 | alofi
# Processing Record 50 of Set 15 | sao joao da barra
# Processing Record 1 of Set 16 | muros
# Processing Record 2 of Set 16 | torbay
# Processing Record 3 of Set 16 | ratnagiri
# Processing Record 4 of Set 16 | nome
# Processing Record 5 of Set 16 | geraldton
# Processing Record 6 of Set 16 | tabuk
# Processing Record 7 of Set 16 | brufut
# Processing Record 8 of Set 16 | khatanga
# Processing Record 9 of Set 16 | hermanus
# Processing Record 10 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 16 | camana
# Processing Record 13 of Set 16 | agadir
# Processing Record 14 of Set 16 | saint george
# Processing Record 15 of Set 16 | roald
# Processing Record 16 of Set 16 | ormond beach
# Processing Record 17 of Set 16 | lorengau
# Processing Record 18 of Set 16 | pangai
# Processing Record 19 of Set 16 | arman
# Processing Record 20 of Set 16 | ballina
# Processing Record 21 of Set 16 | esperance
# Processing Record 22 of Set 16 | pacific grove
# Processing Record 23 of Set 16 | port alfred
# Processing Record 24 of Set 16 | burica
# City not found. Skipping...
# Processing Record 25 of Set 16 | san patricio
# Processing Record 26 of Set 16 | tambura
# Processing Record 27 of Set 16 | east london
# Processing Record 28 of Set 16 | gambela
# Processing Record 29 of Set 16 | bluff
# Processing Record 30 of Set 16 | mahebourg
# Processing Record 31 of Set 16 | faanui
# Processing Record 32 of Set 16 | bambous virieux
# Processing Record 33 of Set 16 | kununurra
# Processing Record 34 of Set 16 | quatre cocos
# Processing Record 35 of Set 16 | blagoyevo
# Processing Record 36 of Set 16 | banda aceh
# Processing Record 37 of Set 16 | nanortalik
# Processing Record 38 of Set 16 | pitea
# Processing Record 39 of Set 16 | evensk
# Processing Record 40 of Set 16 | rio grande
# Processing Record 41 of Set 16 | moranbah
# Processing Record 42 of Set 16 | vanino
# Processing Record 43 of Set 16 | walvis bay
# Processing Record 44 of Set 16 | bengkulu
# Processing Record 45 of Set 16 | georgetown
# Processing Record 46 of Set 16 | lagoa
# Processing Record 47 of Set 16 | clyde river
# Processing Record 48 of Set 16 | whitehorse
# Processing Record 49 of Set 16 | acapulco
# Processing Record 50 of Set 16 | seoul
# Processing Record 1 of Set 17 | aswan
# Processing Record 2 of Set 17 | padang
# Processing Record 3 of Set 17 | hithadhoo
# Processing Record 4 of Set 17 | klaeng
# Processing Record 5 of Set 17 | pangody
# Processing Record 6 of Set 17 | coueron
# Processing Record 7 of Set 17 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 17 | kundiawa
# Processing Record 10 of Set 17 | sao filipe
# Processing Record 11 of Set 17 | zhicheng
# Processing Record 12 of Set 17 | fort nelson
# Processing Record 13 of Set 17 | caravelas
# Processing Record 14 of Set 17 | kavieng
# Processing Record 15 of Set 17 | stykkisholmur
# Processing Record 16 of Set 17 | beringovskiy
# Processing Record 17 of Set 17 | viedma
# Processing Record 18 of Set 17 | san javier
# Processing Record 19 of Set 17 | bowen
# Processing Record 20 of Set 17 | shwebo
# Processing Record 21 of Set 17 | tuktoyaktuk
# Processing Record 22 of Set 17 | gonbad-e qabus
# Processing Record 23 of Set 17 | praia da vitoria
# Processing Record 24 of Set 17 | magistralnyy
# Processing Record 25 of Set 17 | camocim
# Processing Record 26 of Set 17 | torrevieja
# Processing Record 27 of Set 17 | umm lajj
# Processing Record 28 of Set 17 | biak
# Processing Record 29 of Set 17 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 17 | pevek
# Processing Record 31 of Set 17 | kewanee
# Processing Record 32 of Set 17 | shubarshi
# Processing Record 33 of Set 17 | barras
# Processing Record 34 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 17 | pisco
# Processing Record 36 of Set 17 | okha
# Processing Record 37 of Set 17 | sug-aksy
# City not found. Skipping...
# Processing Record 38 of Set 17 | fergus falls
# Processing Record 39 of Set 17 | olafsvik
# Processing Record 40 of Set 17 | nagydobos
# Processing Record 41 of Set 17 | ponta do sol
# Processing Record 42 of Set 17 | betsiamites
# Processing Record 43 of Set 17 | trabzon
# Processing Record 44 of Set 17 | tura
# Processing Record 45 of Set 17 | saravan
# Processing Record 46 of Set 17 | choix
# Processing Record 47 of Set 17 | sao gabriel da cachoeira
# Processing Record 48 of Set 17 | bitung
# Processing Record 49 of Set 17 | talnakh
# Processing Record 50 of Set 17 | leningradskiy
# Processing Record 1 of Set 18 | airai
# Processing Record 2 of Set 18 | berberati
# Processing Record 3 of Set 18 | vila
# Processing Record 4 of Set 18 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 18 | yamada
# Processing Record 6 of Set 18 | kang
# Processing Record 7 of Set 18 | paidha
# Processing Record 8 of Set 18 | ilulissat
# Processing Record 9 of Set 18 | warrnambool
# Processing Record 10 of Set 18 | hambantota
# Processing Record 11 of Set 18 | lebu
# Processing Record 12 of Set 18 | kotelnikovo
# Processing Record 13 of Set 18 | lagos
# Processing Record 14 of Set 18 | presidencia roque saenz pena
# Processing Record 15 of Set 18 | channel-port aux basques
# Processing Record 16 of Set 18 | baykit
# Processing Record 17 of Set 18 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 18 | hisor
# Processing Record 19 of Set 18 | honningsvag
# Processing Record 20 of Set 18 | swan hill
# Processing Record 21 of Set 18 | cidreira
# Processing Record 22 of Set 18 | grand baie
# Processing Record 23 of Set 18 | pimentel
# Processing Record 24 of Set 18 | horsham
# Processing Record 25 of Set 18 | chara
# Processing Record 26 of Set 18 | seymchan
# Processing Record 27 of Set 18 | mackay
# Processing Record 28 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 18 | la libertad
# Processing Record 30 of Set 18 | sorland
# Processing Record 31 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 18 | saint-pierre
# Processing Record 33 of Set 18 | edinburg
# Processing Record 34 of Set 18 | tual
# Processing Record 35 of Set 18 | tuatapere
# Processing Record 36 of Set 18 | alexandria
# Processing Record 37 of Set 18 | scarborough
# Processing Record 38 of Set 18 | fortuna
# Processing Record 39 of Set 18 | coquimbo
# Processing Record 40 of Set 18 | kaeo
# Processing Record 41 of Set 18 | zhigansk
# Processing Record 42 of Set 18 | la ronge
# Processing Record 43 of Set 18 | sitka
# Processing Record 44 of Set 18 | vytegra
# Processing Record 45 of Set 18 | ottumwa
# Processing Record 46 of Set 18 | bubaque
# Processing Record 47 of Set 18 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 18 | kirakira
# Processing Record 49 of Set 18 | husavik
# Processing Record 50 of Set 18 | mapiripan
# Processing Record 1 of Set 19 | harrison
# Processing Record 2 of Set 19 | sur
# Processing Record 3 of Set 19 | kulhudhuffushi
# Processing Record 4 of Set 19 | port lincoln
# Processing Record 5 of Set 19 | ribeira grande
# Processing Record 6 of Set 19 | grindavik
# Processing Record 7 of Set 19 | urumqi
# Processing Record 8 of Set 19 | dudinka
# Processing Record 9 of Set 19 | tessalit
# Processing Record 10 of Set 19 | bac lieu
# Processing Record 11 of Set 19 | catamayo
# Processing Record 12 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 19 | cayenne
# Processing Record 15 of Set 19 | port elizabeth
# Processing Record 16 of Set 19 | shingu
# Processing Record 17 of Set 19 | ararat
# Processing Record 18 of Set 19 | severnyy
# Processing Record 19 of Set 19 | taoudenni
# Processing Record 20 of Set 19 | nadvoitsy
# Processing Record 21 of Set 19 | beloha
# Processing Record 22 of Set 19 | bilaspur
# Processing Record 23 of Set 19 | barranca
# Processing Record 24 of Set 19 | tazovskiy
# Processing Record 25 of Set 19 | dingle
# Processing Record 26 of Set 19 | cedar rapids
# Processing Record 27 of Set 19 | pasighat
# Processing Record 28 of Set 19 | kodinsk
# Processing Record 29 of Set 19 | havelock
# Processing Record 30 of Set 19 | orikum
# Processing Record 31 of Set 19 | mabaruma
# Processing Record 32 of Set 19 | henties bay
# Processing Record 33 of Set 19 | ciudad bolivar
# Processing Record 34 of Set 19 | atbasar
# Processing Record 35 of Set 19 | saint-francois
# Processing Record 36 of Set 19 | kalmunai
# Processing Record 37 of Set 19 | maragogi
# Processing Record 38 of Set 19 | fukue
# Processing Record 39 of Set 19 | saint-augustin
# Processing Record 40 of Set 19 | guiberoua
# Processing Record 41 of Set 19 | bandarbeyla
# Processing Record 42 of Set 19 | ermelo
# Processing Record 43 of Set 19 | boyolangu
# Processing Record 44 of Set 19 | okhotsk
# Processing Record 45 of Set 19 | port keats
# Processing Record 46 of Set 19 | kahului
# Processing Record 47 of Set 19 | saint-philippe
# Processing Record 48 of Set 19 | jaque
# Processing Record 49 of Set 19 | te anau
# Processing Record 50 of Set 19 | pochutla
# Processing Record 1 of Set 20 | makinsk
# Processing Record 2 of Set 20 | innisfail
# Processing Record 3 of Set 20 | mayo
# Processing Record 4 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 20 | requena
# Processing Record 6 of Set 20 | santa rosa
# Processing Record 7 of Set 20 | ghanzi
# Processing Record 8 of Set 20 | salalah
# Processing Record 9 of Set 20 | chenghai
# Processing Record 10 of Set 20 | bethlehem
# Processing Record 11 of Set 20 | la palma
# Processing Record 12 of Set 20 | shiyan
# Processing Record 13 of Set 20 | santa maria
# Processing Record 14 of Set 20 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 20 | abu kamal
# Processing Record 16 of Set 20 | road town
# Processing Record 17 of Set 20 | jawhar
# Processing Record 18 of Set 20 | narsaq
# Processing Record 19 of Set 20 | aldan
# Processing Record 20 of Set 20 | freeport
# Processing Record 21 of Set 20 | mirnyy
# Processing Record 22 of Set 20 | ovsyanka
# Processing Record 23 of Set 20 | polis
# Processing Record 24 of Set 20 | alekseyevka
# Processing Record 25 of Set 20 | nelson bay
# Processing Record 26 of Set 20 | shurugwi
# Processing Record 27 of Set 20 | volga
# Processing Record 28 of Set 20 | bileca
# Processing Record 29 of Set 20 | san quintin
# Processing Record 30 of Set 20 | verkhnyaya balkariya
# Processing Record 31 of Set 20 | faya
# Processing Record 32 of Set 20 | chelyabinsk
# Processing Record 33 of Set 20 | chabahar
# Processing Record 34 of Set 20 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 20 | mount gambier
# Processing Record 36 of Set 20 | birigui
# Processing Record 37 of Set 20 | tahe
# Processing Record 38 of Set 20 | lebedinyy
# Processing Record 39 of Set 20 | san blas
# Processing Record 40 of Set 20 | luis correia
# Processing Record 41 of Set 20 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 20 | pangkalanbuun
# Processing Record 43 of Set 20 | indian head
# Processing Record 44 of Set 20 | tacna
# Processing Record 45 of Set 20 | cabedelo
# Processing Record 46 of Set 20 | motala
# Processing Record 47 of Set 20 | palu
# Processing Record 48 of Set 20 | tabou
# Processing Record 49 of Set 20 | sambava
# Processing Record 50 of Set 20 | punakha
# Processing Record 1 of Set 21 | birao
# Processing Record 2 of Set 21 | pervomayskiy
# Processing Record 3 of Set 21 | zlatoustovsk
# City not found. Skipping...
# Processing Record 4 of Set 21 | khandyga
# Processing Record 5 of Set 21 | lixourion
# Processing Record 6 of Set 21 | popondetta
# Processing Record 7 of Set 21 | coihaique
# Processing Record 8 of Set 21 | yukhnov
# Processing Record 9 of Set 21 | aleksin
# Processing Record 10 of Set 21 | cururupu
# Processing Record 11 of Set 21 | le port
# Processing Record 12 of Set 21 | hof
# Processing Record 13 of Set 21 | acajutla
# Processing Record 14 of Set 21 | tara
# Processing Record 15 of Set 21 | hasaki
# Processing Record 16 of Set 21 | lasa
# Processing Record 17 of Set 21 | gbarnga
# Processing Record 18 of Set 21 | luang prabang
# Processing Record 19 of Set 21 | palmerston
# Processing Record 20 of Set 21 | tarko-sale
# Processing Record 21 of Set 21 | denpasar
# Processing Record 22 of Set 21 | vila do maio
# Processing Record 23 of Set 21 | vuktyl
# Processing Record 24 of Set 21 | kruisfontein
# Processing Record 25 of Set 21 | sao felix do xingu
# Processing Record 26 of Set 21 | chalus
# Processing Record 27 of Set 21 | massakory
# Processing Record 28 of Set 21 | haines junction
# Processing Record 29 of Set 21 | mmabatho
# Processing Record 30 of Set 21 | dinguiraye
# Processing Record 31 of Set 21 | hualmay
# Processing Record 32 of Set 21 | pangnirtung
# Processing Record 33 of Set 21 | poum
# Processing Record 34 of Set 21 | bereznehuvate
# Processing Record 35 of Set 21 | shahrud
# Processing Record 36 of Set 21 | vallenar
# Processing Record 37 of Set 21 | praia
# Processing Record 38 of Set 21 | hofn
# Processing Record 39 of Set 21 | moose factory
# Processing Record 40 of Set 21 | magadan
# Processing Record 41 of Set 21 | ostersund
# Processing Record 42 of Set 21 | ewa beach
# Processing Record 43 of Set 21 | ayorou
# Processing Record 44 of Set 21 | champerico
# Processing Record 45 of Set 21 | saldanha
# Processing Record 46 of Set 21 | farah
# Processing Record 47 of Set 21 | waingapu
# Processing Record 48 of Set 21 | santa isabel do rio negro
# Processing Record 49 of Set 21 | shinshiro
# Processing Record 50 of Set 21 | verkhnevilyuysk
# Processing Record 1 of Set 22 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 22 | dalaba
# Processing Record 3 of Set 22 | christchurch
# Processing Record 4 of Set 22 | vanimo
# Processing Record 5 of Set 22 | liverpool
# Processing Record 6 of Set 22 | irece
# Processing Record 7 of Set 22 | garowe
# Processing Record 8 of Set 22 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 22 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 22 | madikeri
# Processing Record 11 of Set 22 | nioro
# Processing Record 12 of Set 22 | knyaze-volkonskoye
# Processing Record 13 of Set 22 | rio cuarto
# Processing Record 14 of Set 22 | bamnet narong
# Processing Record 15 of Set 22 | baglung
# Processing Record 16 of Set 22 | tayoltita
# Processing Record 17 of Set 22 | sakaiminato
# Processing Record 18 of Set 22 | novoaltaysk
# Processing Record 19 of Set 22 | kukes
# Processing Record 20 of Set 22 | aklavik
# Processing Record 21 of Set 22 | kamaishi
# Processing Record 22 of Set 22 | beroroha
# Processing Record 23 of Set 22 | mandera
# Processing Record 24 of Set 22 | ternate
# Processing Record 25 of Set 22 | talaya
# Processing Record 26 of Set 22 | nyurba
# Processing Record 27 of Set 22 | plettenberg bay
# Processing Record 28 of Set 22 | hovd
# Processing Record 29 of Set 22 | porto novo
# Processing Record 30 of Set 22 | sar-e pul
# Processing Record 31 of Set 22 | greenwood
# Processing Record 32 of Set 22 | mayumba
# Processing Record 33 of Set 22 | kudahuvadhoo
# Processing Record 34 of Set 22 | toora-khem
# Processing Record 35 of Set 22 | vagur
# Processing Record 36 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 22 | port hedland
# Processing Record 38 of Set 22 | naze
# Processing Record 39 of Set 22 | ulaangom
# Processing Record 40 of Set 22 | bonthe
# Processing Record 41 of Set 22 | bababe
# City not found. Skipping...
# Processing Record 42 of Set 22 | longyearbyen
# Processing Record 43 of Set 22 | taft
# Processing Record 44 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 22 | nemuro
# Processing Record 46 of Set 22 | wajima
# Processing Record 47 of Set 22 | vibo valentia
# Processing Record 48 of Set 22 | norman wells
# Processing Record 49 of Set 22 | singaraja
# Processing Record 50 of Set 22 | bima
# Processing Record 1 of Set 23 | tambun
# Processing Record 2 of Set 23 | fare
# Processing Record 3 of Set 23 | dyersburg
# Processing Record 4 of Set 23 | mildura
# Processing Record 5 of Set 23 | tias
# Processing Record 6 of Set 23 | humberto de campos
# Processing Record 7 of Set 23 | ayan
# Processing Record 8 of Set 23 | nuevo casas grandes
# Processing Record 9 of Set 23 | kholtoson
# Processing Record 10 of Set 23 | kloulklubed
# Processing Record 11 of Set 23 | tilichiki
# Processing Record 12 of Set 23 | kargil
# Processing Record 13 of Set 23 | krasnoselkup
# Processing Record 14 of Set 23 | iqaluit
# Processing Record 15 of Set 23 | algiers
# Processing Record 16 of Set 23 | kautokeino
# Processing Record 17 of Set 23 | shelburne
# Processing Record 18 of Set 23 | jadu
# Processing Record 19 of Set 23 | mandleshwar
# Processing Record 20 of Set 23 | dunedin
# Processing Record 21 of Set 23 | changping
# Processing Record 22 of Set 23 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 23 | luganville
# Processing Record 24 of Set 23 | tambacounda
# Processing Record 25 of Set 23 | kirkenaer
# Processing Record 26 of Set 23 | gorodishche
# Processing Record 27 of Set 23 | broken hill
# Processing Record 28 of Set 23 | price
# Processing Record 29 of Set 23 | mudyuga
# City not found. Skipping...
# Processing Record 30 of Set 23 | eenhana
# Processing Record 31 of Set 23 | qeshm
# Processing Record 32 of Set 23 | snasa
# Processing Record 33 of Set 23 | pedernales
# Processing Record 34 of Set 23 | zhenlai
# Processing Record 35 of Set 23 | kamuli
# Processing Record 36 of Set 23 | bossangoa
# Processing Record 37 of Set 23 | virginia beach
# Processing Record 38 of Set 23 | chicama
# Processing Record 39 of Set 23 | tomohon
# Processing Record 40 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 23 | shitanjing
# Processing Record 42 of Set 23 | mtwara
# Processing Record 43 of Set 23 | colmar
# Processing Record 44 of Set 23 | arecibo
# Processing Record 45 of Set 23 | gaogou
# Processing Record 46 of Set 23 | aviles
# Processing Record 47 of Set 23 | ambilobe
# Processing Record 48 of Set 23 | panama city
# Processing Record 49 of Set 23 | golovino
# Processing Record 50 of Set 23 | hay river
# Processing Record 1 of Set 24 | harper
# Processing Record 2 of Set 24 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 24 | jipijapa
# Processing Record 4 of Set 24 | macae
# Processing Record 5 of Set 24 | novoagansk
# Processing Record 6 of Set 24 | atambua
# Processing Record 7 of Set 24 | monsenhor gil
# Processing Record 8 of Set 24 | buala
# Processing Record 9 of Set 24 | wagar
# Processing Record 10 of Set 24 | huarmey
# Processing Record 11 of Set 24 | gazanjyk
# Processing Record 12 of Set 24 | eliot
# Processing Record 13 of Set 24 | maua
# Processing Record 14 of Set 24 | coxim
# Processing Record 15 of Set 24 | inhambane
# Processing Record 16 of Set 24 | muroto
# Processing Record 17 of Set 24 | iringa
# Processing Record 18 of Set 24 | bereda
# Processing Record 19 of Set 24 | lompoc
# Processing Record 20 of Set 24 | taicheng
# Processing Record 21 of Set 24 | marienburg
# Processing Record 22 of Set 24 | saint anthony
# Processing Record 23 of Set 24 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 24 | vladyslavivka
# Processing Record 25 of Set 24 | ampanihy
# Processing Record 26 of Set 24 | yumen
# Processing Record 27 of Set 24 | watsa
# Processing Record 28 of Set 24 | riberalta
# Processing Record 29 of Set 24 | angoche
# Processing Record 30 of Set 24 | bar harbor
# Processing Record 31 of Set 24 | huaraz
# Processing Record 32 of Set 24 | rocha
# Processing Record 33 of Set 24 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 24 | annau
# Processing Record 35 of Set 24 | ouargaye
# Processing Record 36 of Set 24 | waddan
# Processing Record 37 of Set 24 | luoyang
# Processing Record 38 of Set 24 | karacabey
# Processing Record 39 of Set 24 | molteno
# Processing Record 40 of Set 24 | shimoda
# Processing Record 41 of Set 24 | kidal
# Processing Record 42 of Set 24 | solsvik
# City not found. Skipping...
# Processing Record 43 of Set 24 | gold coast
# Processing Record 44 of Set 24 | cianorte
# Processing Record 45 of Set 24 | praya
# Processing Record 46 of Set 24 | northfield
# Processing Record 47 of Set 24 | bafq
# Processing Record 48 of Set 24 | mazzarino
# Processing Record 49 of Set 24 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 24 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 1 of Set 25 | dingzhou
# Processing Record 2 of Set 25 | estelle
# Processing Record 3 of Set 25 | flinders
# Processing Record 4 of Set 25 | coolum beach
# Processing Record 5 of Set 25 | ajuchitlan
# Processing Record 6 of Set 25 | kawalu
# Processing Record 7 of Set 25 | kortkeros
# Processing Record 8 of Set 25 | dumas
# Processing Record 9 of Set 25 | balagansk
# Processing Record 10 of Set 25 | tezu
# Processing Record 11 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 25 | concordia
# Processing Record 13 of Set 25 | kurmanayevka
# Processing Record 14 of Set 25 | envira
# Processing Record 15 of Set 25 | rio gallegos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
len(city_data)
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description","Rain (inches)","Snow (inches)"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                      City Country    Lat     Lng  Max Temp  Humidity  \
# 0                  Dikson      RU  73.51   80.55     36.68        93
# 1              Beni Mazar      EG  28.50   30.80     82.92        27
# 2  Sao Miguel Do Araguaia      BR -13.28  -50.16     68.14        63
# 3                  Namibe      AO -15.20   12.15     71.22        46
# 4                  Barrow      US  71.29 -156.79     37.40        86
#
#    Cloudiness  Wind Speed    Description  Rain (inches)  Snow (inches)
# 0         100       17.87     light rain           0.91            0.0
# 1           0        1.81      clear sky           0.00            0.0
# 2          24        2.42     few clouds           0.00            0.0
# 3           0        6.78      clear sky           0.00            0.0
# 4          75       10.29  broken clouds           0.00            0.0

# %%
# Save the new DataFrame as a CSV file to be used for Part 2.
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Upload the CSV file as part of your submission as WeatherPy_database.csv.
